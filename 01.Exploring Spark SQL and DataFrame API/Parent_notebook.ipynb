# %%
dbutils.notebook().help()

# %%
execution_msg = dbutils.notebook().run("./Child_notebook_1",timeout_seconds=100)

# %%
print(execution_msg)

# %%
execution_status = dbutils.notebook.run(
    path="./Child_notebook_1",
    timeout_seconds=100,
    arguments={
        "top_n_records": "100",
        "environment": "Production",
        "name": "Isha",
        "technology": "4G",
    },
)
print(execution_status)
