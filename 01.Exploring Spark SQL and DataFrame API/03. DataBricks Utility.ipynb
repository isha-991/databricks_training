# %%
dbutils.help()

# %%
dbutils.fs.ls('/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/')

# %%
dbutils.widgets.combobox(
    name="top_n_records",
    defaultValue="5",
    choices=["5", "10", "20", "50", "100"],
    label="Top N Records",
)

# %%
print(dbutils.widgets.get("top_n_records"))

# %%
dbutils.widgets.dropdown(name="environment",defaultValue="dev",choices=["dev","qa","pre prod"],label="Environment")

# %%
dbutils.widgets.text(name="Enter_Name",defaultValue="Anonymous",label="Name")

# %%
dbutils.widgets.multiselect(name='technology',defaultValue="2G",choices=["2G","3G","4G","5G"],label="Technology")

# %%
dbutils.widgets.remove('environment')

# %%
dbutils.widgets.removeAll()
