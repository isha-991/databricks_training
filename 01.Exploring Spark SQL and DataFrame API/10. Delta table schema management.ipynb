# %%
# %sql
USE CATALOG quickstart_catalog;

# %%
spark.read.csv(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",header=True,inferSchema=True).write.mode("overwrite").saveAsTable("quickstart_schema.users_new")

# %%
spark.read.csv(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_006_new_column_education.csv",header=True,inferSchema=True).write.option("mergeSchema", "true").mode("append").saveAsTable("quickstart_catalog.quickstart_schema.users_new")

# %%
from pyspark.sql.functions import col 
spark.read.table("quickstart_catalog.quickstart_schema.users_new").filter(col("id").between(2501,2505)).display()

# %%
spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_012_less_columns.csv",
    header=True,
    inferSchema=True
).write.mode("append").saveAsTable(
    "quickstart_schema.users_new"
)

# %%
from pyspark.sql.functions import col 
spark.read.table("quickstart_schema.users_new").filter(col("id").between(5501,5505)).display()

# %%
from pyspark.sql.functions import col

spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_013_less_columns_with_different_column_names.csv",
    header=True,
    inferSchema=True
).select(
    col("user_id").alias("id"),
    col("full_name").alias("name")
).write.mode("append").saveAsTable(
    "quickstart_schema.users_new"
)

# %%
spark.read.table("quickstart_schema.users_new") \
    .filter(col("id").between(6001, 6002)) \
    .display()

# %%
spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_013_datatype_mismatch_dob.csv",
    header=True,
    inferSchema=True,
).write.mode("append").saveAsTable("quickstart_schema.users_new")
