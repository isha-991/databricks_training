# %%
print("Invoked Child notebook 01")

# %%
dbutils.widgets.combobox(
    name="top_n_records",
    defaultValue="5",
    choices=["5", "10", "15", "20"],
    label="Top n Records",
)
 
dbutils.widgets.dropdown(
    name="environment",
    defaultValue="Development",
    choices=["Development", "QA Environment", "Pre Production Environment"],
    label="ENvironment Type",
)
 
dbutils.widgets.text(name="name", defaultValue="Anonymous", label="Enter name")
dbutils.widgets.multiselect(name="technology", defaultValue="2G", choices=["2G","3G","4G","5G"], label="Technology")

# %%
dbutils.notebook.exit(
    f"Executed successfully with {dbutils.widgets.get('top_n_records')}, {dbutils.widgets.get('environment')}, {dbutils.widgets.get('name')}, {dbutils.widgets.get('technology')}"
)
